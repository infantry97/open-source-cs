# %% [markdown]
# <a href="https://colab.research.google.com/github/infantry97/open-source-cs/blob/master/zillow_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
os.getcwd #tells you what dir you're working in, if you happen to be running python on your laptop
# Out:
# <function posix.getcwd>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
pd.read_csv('/content/dataFiles/results2.csv')
# Out:
#     RegionID                      RegionName  ... ForecastYChange  CurrentYChange
# 0     394913                        New York  ...        0.024815        0.016822
# 1     753899  Los Angeles-Long Beach-Anaheim  ...        0.018667        0.017836
# 2     394463                         Chicago  ...        0.006289        0.012094
# 3     394514               Dallas-Fort Worth  ...        0.032765        0.022331
# 4     394974                    Philadelphia  ...        0.021080        0.031951
# 5     394692                         Houston  ...        0.018545        0.008633
# 6     395209                      Washington  ...        0.017180        0.023268
# 7     394856           Miami-Fort Lauderdale  ...        0.018888        0.007613
# 8     394347                         Atlanta  ...        0.067476        0.047350
# 9     394404                          Boston  ...        0.020851        0.028897
# ...

# %%
data = pd.read_csv('/content/dataFiles/results2.csv')

# %%
data.to_csv('/content/dataFiles/zillow.csv') #this is how to export pandas dataframes to files
